# %%
import pandas as pd
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

data = pd.read_csv("D:\\Internship Progress\\WEEK3\\cafe refresh1.csv")

text_column = 'full_text'

analyzer = SentimentIntensityAnalyzer()

def classify_sentiment(text):
    sentiment_score = analyzer.polarity_scores(text)
    compound_score = sentiment_score['compound']

    if compound_score >= 0.05:
        return 'Positive'
    elif compound_score <= -0.05:
        return 'Negative'
    else:
        return 'Neutral'

data['sentiment'] = data[text_column].apply(classify_sentiment)

data.to_csv("D:\\Internship Progress\\WEEK3\\cafe refresh1.csv", index=False)

print(data)

count_positive = 0
count_negative = 0
count_neutral = 0

for sentiment in data['sentiment']:
    if sentiment == 'Positive':
        count_positive += 1
    elif sentiment == 'Negative':
        count_negative += 1
    elif sentiment == 'Neutral':
        count_neutral += 1

print(f"Number of Positive Sentiments: {count_positive}")
print(f"Number of Negative Sentiments: {count_negative}")
print(f"Number of Neutral Sentiments: {count_neutral}")

per1 = 0
per2 = 0
per3 = 0
total = len(data)
positive_response1 = (count_positive / total) * 100
negative_response1 = (count_negative / total) * 100
neutral_response1 = (count_neutral / total) * 100

print("postitive_response", positive_response1)
print("negative_response", negative_response1)
print("neutral_response", neutral_response1)
# Out:
#                                             full_text sentiment
# 0   A lot of folks on twitter already spoke about ...  Positive
# 1    bangalore airport ninchi baitaki raagane micr...   Neutral
# 2    if you have an early morning flight to catch ...  Positive
# 3   do check out mitti cafe if you are around the ...   Neutral
# 4   be a part of history in the making today when ...   Neutral
# 5   tomorrow a project very special to me  from my...  Positive
# 6    airtel presence not able to get 5g network in...  Positive
# 7   let me also say this  bangalore airport has a ...  Positive
# 8   installation of the kfc brew d bar  amp  cafe ...   Neutral
# 9   anyone just want to go hang out in a cafe bar ...  Positive
# 10  til there is a karnataka style restaurant at t...   Neutral
# 11  bubble  a stranger offered me a co founder rol...   Neutral
# 12   peak bengaluru so far i ve seen the lovely we...  Positive
# 13  playing w fire and life goes on just played in...  Positive
# ...

# %%
import pandas as pd
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

data = pd.read_csv("D:\\Internship Progress\\WEEK3\\check-in.csv")

text_column = 'full_text'

analyzer = SentimentIntensityAnalyzer()

def classify_sentiment(text):
    sentiment_score = analyzer.polarity_scores(text)
    compound_score = sentiment_score['compound']

    if compound_score >= 0.05:
        return 'Positive'
    elif compound_score <= -0.05:
        return 'Negative'
    else:
        return 'Neutral'

data['sentiment'] = data[text_column].apply(classify_sentiment)

data.to_csv("D:\\Internship Progress\\WEEK3\\check-in.csv", index=False)

print(data)

count_positive = 0
count_negative = 0
count_neutral = 0

for sentiment in data['sentiment']:
    if sentiment == 'Positive':
        count_positive += 1
    elif sentiment == 'Negative':
        count_negative += 1
    elif sentiment == 'Neutral':
        count_neutral += 1

print(f"Number of Positive Sentiments: {count_positive}")
print(f"Number of Negative Sentiments: {count_negative}")
print(f"Number of Neutral Sentiments: {count_neutral}")

per1 = 0
per2 = 0
per3 = 0
total = len(data)
positive_response2 = (count_positive / total) * 100
negative_response2 = (count_negative / total) * 100
neutral_response2 = (count_neutral / total) * 100

print("postitive_response", positive_response2)
print("negative_response", negative_response2)
print("neutral_response", neutral_response2)
# Out:
#                                             full_text sentiment
# 0   bangalore airport is the best airport ive been...  Positive
# 1   yatra was supposed to reduce time apparently r...  Positive
# 2    i entered 2 hours before departure thats 120 ...  Positive
# 3   had some issue checking in online  but prajawa...  Positive
# 4     my house in bangalore to my parents house in...  Positive
# ..                                                ...       ...
# 93  safiranand my experience at bangalore airport ...  Positive
# 94    did i support any of these goons in my tweet...  Positive
# 95   yes few years back almost missed a flight to ...  Positive
# 96  today i experienced the future of travel exper...  Positive
# 97  i had a good experience in my flights but it w...  Negative
#
# [98 rows x 2 columns]
# Number of Positive Sentiments: 60
# Number of Negative Sentiments: 31
# Number of Neutral Sentiments: 7
# postitive_response 61.224489795918366
# ...

# %%
import pandas as pd
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

data = pd.read_csv("D:\\Internship Progress\\WEEK3\\food refresh1.csv")

text_column = 'full_text'

analyzer = SentimentIntensityAnalyzer()

def classify_sentiment(text):
    sentiment_score = analyzer.polarity_scores(text)
    compound_score = sentiment_score['compound']

    if compound_score >= 0.05:
        return 'Positive'
    elif compound_score <= -0.05:
        return 'Negative'
    else:
        return 'Neutral'

data['sentiment'] = data[text_column].apply(classify_sentiment)

data.to_csv("D:\\Internship Progress\\WEEK3\\food refresh1.csv", index=False)

print(data)

count_positive = 0
count_negative = 0
count_neutral = 0

for sentiment in data['sentiment']:
    if sentiment == 'Positive':
        count_positive += 1
    elif sentiment == 'Negative':
        count_negative += 1
    elif sentiment == 'Neutral':
        count_neutral += 1

print(f"Number of Positive Sentiments: {count_positive}")
print(f"Number of Negative Sentiments: {count_negative}")
print(f"Number of Neutral Sentiments: {count_neutral}")

per1 = 0
per2 = 0
per3 = 0
total = len(data)
positive_response3 = (count_positive / total) * 100
negative_response3 = (count_negative / total) * 100
neutral_response3 = (count_neutral / total) * 100

print("postitive_response", positive_response3)
print("negative_response", negative_response3)
print("neutral_response", neutral_response3)
# Out:
#                                             full_text sentiment
# 0   they came and sat near me picked up some remna...  Positive
# 1    blrairport bangalore airport outside food cou...  Positive
# 2   as soon as we step out of bangalore airport bu...  Negative
# 3   i m not kidding  bangalore airport s food cour...  Positive
# 4    when i traveled for bangalore airport from my...  Negative
# 5   bangalore airport  you seem to have forgotten ...  Negative
# 6   til there is a karnataka style restaurant at t...   Neutral
# 7     bangalore airport food court  was immersed i...   Neutral
# 8   they came and picked up some remnants of the p...  Positive
# 9   huh  bangalore airport now has a pretty compre...  Positive
# 10  there was a time  2011 to be precise  when the...   Neutral
# 11  i m fact the last sparrows i saw this close up...  Positive
# 12  it s getting better  in my opinion bangalore a...  Positive
# 13   thank you for staying connected  the coupon i...  Positive
# ...

# %%
import pandas as pd
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

data = pd.read_csv("D:\\Internship Progress\\WEEK3\\hospitality_1.csv")

text_column = 'full_text'

analyzer = SentimentIntensityAnalyzer()

def classify_sentiment(text):
    sentiment_score = analyzer.polarity_scores(text)
    compound_score = sentiment_score['compound']

    if compound_score >= 0.05:
        return 'Positive'
    elif compound_score <= -0.05:
        return 'Negative'
    else:
        return 'Neutral'

data['sentiment'] = data[text_column].apply(classify_sentiment)

data.to_csv("D:\\Internship Progress\\WEEK3\\hospitality_1.csv", index=False)

print(data)

count_positive = 0
count_negative = 0
count_neutral = 0

for sentiment in data['sentiment']:
    if sentiment == 'Positive':
        count_positive += 1
    elif sentiment == 'Negative':
        count_negative += 1
    elif sentiment == 'Neutral':
        count_neutral += 1

print(f"Number of Positive Sentiments: {count_positive}")
print(f"Number of Negative Sentiments: {count_negative}")
print(f"Number of Neutral Sentiments: {count_neutral}")

per1 = 0
per2 = 0
per3 = 0
total = len(data)
positive_response4 = (count_positive / total) * 100
negative_response4 = (count_negative / total) * 100
neutral_response4 = (count_neutral / total) * 100

print("postitive_response", positive_response4)
print("negative_response", negative_response4)
print("neutral_response", neutral_response4)
# Out:
#                                             full_text sentiment
# 0   oh please bangalore airport never seen such ho...  Positive
# 1   superb hospitality and exceptional service by ...  Positive
# 2   always a pleasure to visit the lounge to banga...  Positive
# 3   harassed at the bangalore airport today by you...  Negative
# 4    unmatched hospitality and grace  thank you ta...  Positive
# 5    sure will be back soon  must commend you for ...  Positive
# 6   waiting airport to fly to kolkata  what a beau...  Positive
# 7   i discovered  swissness while working at  bang...  Positive
# 8   hotels near bangalore airport   internation ai...  Positive
# 9   seamless travel  exceptional comfort experienc...  Positive
# 10   thank you kempegowda bangalore airport    for...  Positive
# 11  now vistara has only one manager for whole ban...  Negative
# 12   at the blr lounge bangalore airport while wai...  Positive
# 13  i travelled by bus route 8 from bangalore airp...  Positive
# ...

# %%
import pandas as pd
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

data = pd.read_csv("D:\\Internship Progress\\WEEK3\\hospitality_2.csv")

text_column = 'full_text'

analyzer = SentimentIntensityAnalyzer()

def classify_sentiment(text):
    sentiment_score = analyzer.polarity_scores(text)
    compound_score = sentiment_score['compound']

    if compound_score >= 0.05:
        return 'Positive'
    elif compound_score <= -0.05:
        return 'Negative'
    else:
        return 'Neutral'

data['sentiment'] = data[text_column].apply(classify_sentiment)

data.to_csv("D:\\Internship Progress\\WEEK3\\hospitality_2.csv", index=False)

print(data)

count_positive = 0
count_negative = 0
count_neutral = 0

for sentiment in data['sentiment']:
    if sentiment == 'Positive':
        count_positive += 1
    elif sentiment == 'Negative':
        count_negative += 1
    elif sentiment == 'Neutral':
        count_neutral += 1

print(f"Number of Positive Sentiments: {count_positive}")
print(f"Number of Negative Sentiments: {count_negative}")
print(f"Number of Neutral Sentiments: {count_neutral}")

per1 = 0
per2 = 0
per3 = 0
total = len(data)
positive_response5 = (count_positive / total) * 100
negative_response5 = (count_negative / total) * 100
neutral_response5 = (count_neutral / total) * 100

print("postitive_response", positive_response5)
print("negative_response", negative_response5)
print("neutral_response", neutral_response5)
# Out:
#                                             full_text sentiment
# 0   oh please bangalore airport  \nnever seen such...  Positive
# 1    harassed at the bangalore airport today by yo...  Negative
# 2   seamless travel  exceptional comfort experienc...  Positive
# 3   superb hospitality and exceptional service by ...  Positive
# 4   hotels near bangalore airport   internation ai...  Positive
# 5     some taj are very bad  eg  the one near bang...  Negative
# 6   it was really nice experience here at bangalor...  Positive
# 7   always a pleasure to visit the lounge to banga...  Positive
# 8   while most of my experience with the airport s...  Positive
# 9      bangalore airport lounge ambience and hospi...  Positive
# 10  lounge experience was good in bangalore airpor...  Positive
# 11  worst experience of travelling with  at bangal...  Negative
# 12  one direct has partnered with plaza premium gr...  Positive
# 13    so  i have been in bangalore launch may time...  Positive
# ...

# %%
import pandas as pd
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

data = pd.read_csv("D:\\Internship Progress\\WEEK3\\immigration_1.csv")

text_column = 'full_text'

analyzer = SentimentIntensityAnalyzer()

def classify_sentiment(text):
    sentiment_score = analyzer.polarity_scores(text)
    compound_score = sentiment_score['compound']

    if compound_score >= 0.05:
        return 'Positive'
    elif compound_score <= -0.05:
        return 'Negative'
    else:
        return 'Neutral'

data['sentiment'] = data[text_column].apply(classify_sentiment)

data.to_csv("D:\\Internship Progress\\WEEK3\\immigration_1.csv", index=False)

print(data)

count_positive = 0
count_negative = 0
count_neutral = 0

for sentiment in data['sentiment']:
    if sentiment == 'Positive':
        count_positive += 1
    elif sentiment == 'Negative':
        count_negative += 1
    elif sentiment == 'Neutral':
        count_neutral += 1

print(f"Number of Positive Sentiments: {count_positive}")
print(f"Number of Negative Sentiments: {count_negative}")
print(f"Number of Neutral Sentiments: {count_neutral}")

per1 = 0
per2 = 0
per3 = 0
total = len(data)
positive_response6 = (count_positive / total) * 100
negative_response6= (count_negative / total) * 100
neutral_response6= (count_neutral / total) * 100

print("postitive_response", positive_response6)
print("negative_response", negative_response6)
print("neutral_response", neutral_response6)
# Out:
#                                             full_text sentiment
# 0   immigration for international arrivals at bang...  Positive
# 1      sir nothing beats efficiency of bangalore a...  Negative
# 2   immigration process at bangalore airport is fa...  Positive
# 3     recently had an interesting conversation at ...  Positive
# 4   bangalore airport arrival lounge is amazingly ...  Positive
# ..                                                ...       ...
# 90  the protocol on bangalore airport is that the ...   Neutral
# 91  sakshijoshii a friend of mine landed from muni...  Positive
# 92   i can confirm about blr airport  came back fr...  Positive
# 93   ohh i saw the same in bangalore airport right...   Neutral
# 94   woman with 2 small kids stuck for 4 days at b...  Positive
#
# [95 rows x 2 columns]
# Number of Positive Sentiments: 42
# Number of Negative Sentiments: 33
# Number of Neutral Sentiments: 20
# postitive_response 44.21052631578947
# ...

# %%
import pandas as pd
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

data = pd.read_csv("D:\\Internship Progress\\WEEK3\\lounge refresh.csv")

text_column = 'full_text'

analyzer = SentimentIntensityAnalyzer()

def classify_sentiment(text):
    sentiment_score = analyzer.polarity_scores(text)
    compound_score = sentiment_score['compound']

    if compound_score >= 0.05:
        return 'Positive'
    elif compound_score <= -0.05:
        return 'Negative'
    else:
        return 'Neutral'

data['sentiment'] = data[text_column].apply(classify_sentiment)

data.to_csv("D:\\Internship Progress\\WEEK3\\lounge refresh.csv", index=False)

print(data)

count_positive = 0
count_negative = 0
count_neutral = 0

for sentiment in data['sentiment']:
    if sentiment == 'Positive':
        count_positive += 1
    elif sentiment == 'Negative':
        count_negative += 1
    elif sentiment == 'Neutral':
        count_neutral += 1

print(f"Number of Positive Sentiments: {count_positive}")
print(f"Number of Negative Sentiments: {count_negative}")
print(f"Number of Neutral Sentiments: {count_neutral}")

per1 = 0
per2 = 0
per3 = 0
total = len(data)
positive_response7 = (count_positive / total) * 100
negative_response7 = (count_negative / total) * 100
neutral_response7 = (count_neutral / total) * 100

print("postitive_response", positive_response7)
print("negative_response", negative_response7)
print("neutral_response", neutral_response7)
# Out:
#                                             full_text sentiment
# 0    frustrated and upset about mastercard elite c...  Negative
# 1   bangalore airport lounge and credit card acces...  Positive
# 2    blrairport 080 lounge on bangalore airport is...  Positive
# 3   again  i used it at bangalore airport  excelle...  Positive
# 4   also found this at bangalore airport t1 lounge...  Positive
# ..                                                ...       ...
# 69  bangalore airport domestic lounge is so average     Neutral
# 70   niyosupport can you please let me know the de...  Positive
# 71  can you please list all the axis cards  debit ...  Positive
# 72  i swiped three cards to enter the bangalore ai...   Neutral
# 73  there is no going back from the 080 lounge at ...  Negative
#
# [74 rows x 2 columns]
# Number of Positive Sentiments: 47
# Number of Negative Sentiments: 15
# Number of Neutral Sentiments: 12
# postitive_response 63.51351351351351
# ...

# %%
import pandas as pd
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

data = pd.read_csv("D:\\Internship Progress\\WEEK3\\passport.csv")

text_column = 'full_text'

analyzer = SentimentIntensityAnalyzer()

def classify_sentiment(text):
    sentiment_score = analyzer.polarity_scores(text)
    compound_score = sentiment_score['compound']

    if compound_score >= 0.05:
        return 'Positive'
    elif compound_score <= -0.05:
        return 'Negative'
    else:
        return 'Neutral'

data['sentiment'] = data[text_column].apply(classify_sentiment)

data.to_csv("D:\\Internship Progress\\WEEK3\\passport.csv", index=False)

print(data)

count_positive = 0
count_negative = 0
count_neutral = 0

for sentiment in data['sentiment']:
    if sentiment == 'Positive':
        count_positive += 1
    elif sentiment == 'Negative':
        count_negative += 1
    elif sentiment == 'Neutral':
        count_neutral += 1

print(f"Number of Positive Sentiments: {count_positive}")
print(f"Number of Negative Sentiments: {count_negative}")
print(f"Number of Neutral Sentiments: {count_neutral}")

per1 = 0
per2 = 0
per3 = 0
total = len(data)
positive_response8 = (count_positive / total) * 100
negative_response8 = (count_negative / total) * 100
neutral_response8 = (count_neutral / total) * 100

print("postitive_response", positive_response8)
print("negative_response", negative_response8)
print("neutral_response", neutral_response8)
# Out:
#                                             full_text sentiment
# 0   stopped from leaving india at bangalore airpor...  Negative
# 1    sos my wife with chinese passport and valid o...  Positive
# 2   mam  indian passport valid more than 5 months ...  Positive
# 3   my own experience earlier this month at bangal...  Negative
# 4   desi british passport holder  they always comm...   Neutral
# ..                                                ...       ...
# 70  traveller at bangalore airport led in dark roo...   Neutral
# 71       immigration officer at bangalore airport ...  Negative
# 72   stopped from leaving india at bangalore airpo...  Negative
# 73  at bangalore airport traveller asked to fold t...  Positive
# 74    thank you inspector ashish and mr  kumndan f...  Positive
#
# [75 rows x 2 columns]
# Number of Positive Sentiments: 33
# Number of Negative Sentiments: 29
# Number of Neutral Sentiments: 13
# postitive_response 44.0
# negative_response 38.666666666666664
# ...

# %%
import pandas as pd
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

data = pd.read_csv("D:\\Internship Progress\\WEEK3\\restarunt refresh1.csv")

text_column = 'full_text'

analyzer = SentimentIntensityAnalyzer()

def classify_sentiment(text):
    sentiment_score = analyzer.polarity_scores(text)
    compound_score = sentiment_score['compound']

    if compound_score >= 0.05:
        return 'Positive'
    elif compound_score <= -0.05:
        return 'Negative'
    else:
        return 'Neutral'

data['sentiment'] = data[text_column].apply(classify_sentiment)

data.to_csv("D:\\Internship Progress\\WEEK3\\restarunt refresh1.csv", index=False)

print(data)

count_positive = 0
count_negative = 0
count_neutral = 0

for sentiment in data['sentiment']:
    if sentiment == 'Positive':
        count_positive += 1
    elif sentiment == 'Negative':
        count_negative += 1
    elif sentiment == 'Neutral':
        count_neutral += 1

print(f"Number of Positive Sentiments: {count_positive}")
print(f"Number of Negative Sentiments: {count_negative}")
print(f"Number of Neutral Sentiments: {count_neutral}")

per1 = 0
per2 = 0
per3 = 0
total = len(data)
positive_response9 = (count_positive / total) * 100
negative_response9 = (count_negative / total) * 100
neutral_response9 = (count_neutral / total) * 100

print("postitive_response", positive_response9)
print("negative_response", negative_response9)
print("neutral_response", neutral_response9)
# Out:
#                                             full_text sentiment
# 0   i don' t call india the land of thalis lightly...   Neutral
# 1   landed in bangalore airport  pleasantly surpri...  Positive
# 2   i want to open a vegan restaurant in bangalore...  Positive
# 3    blr airport  bbmp comm   it was surprising to...  Negative
# 4   even though bangalore airport may have the wor...  Positive
# ..                                                ...       ...
# 73  you cannot fight with the restaurant people at...   Neutral
# 74  hi  freshmenuindia i might have left behind my...  Positive
# 75   i love la alta vista about bangalore airport ...  Positive
# 76    low class business   bangalore airport itsel...  Negative
# 77    not at bangalore airport  they re so fat  fe...   Neutral
#
# [78 rows x 2 columns]
# Number of Positive Sentiments: 48
# Number of Negative Sentiments: 13
# Number of Neutral Sentiments: 17
# postitive_response 61.53846153846154
# ...

# %%
import pandas as pd
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

data = pd.read_csv("D:\\Internship Progress\\WEEK3\\security check.csv")

text_column = 'full_text'

analyzer = SentimentIntensityAnalyzer()

def classify_sentiment(text):
    sentiment_score = analyzer.polarity_scores(text)
    compound_score = sentiment_score['compound']

    if compound_score >= 0.05:
        return 'Positive'
    elif compound_score <= -0.05:
        return 'Negative'
    else:
        return 'Neutral'

data['sentiment'] = data[text_column].apply(classify_sentiment)
data.to_csv("D:\\Internship Progress\\WEEK3\\security check.csv", index=False)

print(data)

count_positive = 0
count_negative = 0
count_neutral = 0

for sentiment in data['sentiment']:
    if sentiment == 'Positive':
        count_positive += 1
    elif sentiment == 'Negative':
        count_negative += 1
    elif sentiment == 'Neutral':
        count_neutral += 1

print(f"Number of Positive Sentiments: {count_positive}")
print(f"Number of Negative Sentiments: {count_negative}")
print(f"Number of Neutral Sentiments: {count_neutral}")

per1 = 0
per2 = 0
per3 = 0
total = len(data)
positive_response10 = (count_positive / total) * 100
negative_response10 = (count_negative / total) * 100
neutral_response10 = (count_neutral / total) * 100

print("postitive_response", positive_response10)
print("negative_response", negative_response10)
print("neutral_response", neutral_response10)
# Out:
#                                             full_text sentiment
# 0     bangalore airport security check is so organ...  Positive
# 1   bangalore airport security check process is on...  Positive
# 2   and finally with help of friends booked qatar ...  Positive
# 3   he was beside me in bangalore airport security...  Positive
# 4   again at bangalore airport security check toda...   Neutral
# 5   massive traffic jam since 4 30 pm  and full qu...  Positive
# 6   normally since most of my trips are short  i t...  Positive
# 7   i did not carry an id flying from  bangalore  ...  Positive
# 8          crowd at bangalore airport security check   Positive
# 9   an update  the state wise regulations for utta...   Neutral
# 10   sir  if your men have to remove every single ...   Neutral
# 11    today at bangalore airport security check  i...  Positive
# 12  there is a comedy on airport security check an...  Positive
# 13    expect delays at bangalore airport  security...  Positive
# ...

# %%
import pandas as pd
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

data = pd.read_csv("D:\\Internship Progress\\WEEK3\\visa.csv")

text_column = 'full_text'

analyzer = SentimentIntensityAnalyzer()

def classify_sentiment(text):
    sentiment_score = analyzer.polarity_scores(text)
    compound_score = sentiment_score['compound']

    if compound_score >= 0.05:
        return 'Positive'
    elif compound_score <= -0.05:
        return 'Negative'
    else:
        return 'Neutral'

data['sentiment'] = data[text_column].apply(classify_sentiment)
data.to_csv("D:\\Internship Progress\\WEEK3\\visa.csv", index=False)

print(data)

count_positive = 0
count_negative = 0
count_neutral = 0

for sentiment in data['sentiment']:
    if sentiment == 'Positive':
        count_positive += 1
    elif sentiment == 'Negative':
        count_negative += 1
    elif sentiment == 'Neutral':
        count_neutral += 1

print(f"Number of Positive Sentiments: {count_positive}")
print(f"Number of Negative Sentiments: {count_negative}")
print(f"Number of Neutral Sentiments: {count_neutral}")

per1 = 0
per2 = 0
per3 = 0
total = len(data)
positive_response11 = (count_positive / total) * 100
negative_response11 = (count_negative / total) * 100
neutral_response11 = (count_neutral / total) * 100

print("postitive_response", positive_response11)
print("negative_response", negative_response11)
print("neutral_response", neutral_response11)
# Out:
#                                             full_text sentiment
# 0   recently scammed by airasia at bangalore airpo...  Negative
# 1   kushanmitra canada has all the leverage  5 eye...   Neutral
# 2   why is coral card  visa platinum international...  Negative
# 3   so many many passengers are facing inconvenien...  Positive
# 4   i had a good experience in my flights  but  it...  Negative
# 5    is the paytm visa debit card accessible for b...   Neutral
# 6    thrishul not travelling is a choice but it s ...  Positive
# 7   why am i not able to access the lounge at bang...  Positive
# 8   what is this bizarre rule  lots of issues with...  Negative
# 9    worst pathetic service at bangalore airport  ...  Negative
# 10   had a sorry figure at mumbai and bangalore ai...  Negative
# 11  at bangalore airport staff needs to be educate...  Positive
# 12  just went through checkin  security and visa c...  Negative
# 13  stuck in bangalore airport because of a visa i...  Positive
# ...

# %%
import pandas as pd
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

data = pd.read_csv("D:\\Internship Progress\\WEEK3\\waiting referesh.csv")

text_column = 'full_text'

analyzer = SentimentIntensityAnalyzer()

def classify_sentiment(text):
    sentiment_score = analyzer.polarity_scores(text)
    compound_score = sentiment_score['compound']

    if compound_score >= 0.05:
        return 'Positive'
    elif compound_score <= -0.05:
        return 'Negative'
    else:
        return 'Neutral'

data['sentiment'] = data[text_column].apply(classify_sentiment)
data.to_csv("D:\\Internship Progress\\WEEK3\\waiting referesh.csv", index=False)

print(data)

count_positive = 0
count_negative = 0
count_neutral = 0

for sentiment in data['sentiment']:
    if sentiment == 'Positive':
        count_positive += 1
    elif sentiment == 'Negative':
        count_negative += 1
    elif sentiment == 'Neutral':
        count_neutral += 1

print(f"Number of Positive Sentiments: {count_positive}")
print(f"Number of Negative Sentiments: {count_negative}")
print(f"Number of Neutral Sentiments: {count_neutral}")

per1 = 0
per2 = 0
per3 = 0
total = len(data)
positive_response12 = (count_positive / total) * 100
negative_response12 = (count_negative / total) * 100
neutral_response12 = (count_neutral / total) * 100

print("postitive_response", positive_response12)
print("negative_response", negative_response12)
print("neutral_response", neutral_response12)
# Out:
#                                             full_text sentiment
# 0   this airline is just a pain after waiting for ...  Negative
# 1   i remember i was sitting in bangalore airport ...   Neutral
# 2    unstablemaria and then you ll be waiting at t...   Neutral
# 3   as much as bangalore airport t2 is wonderful i...  Negative
# 4   looks like the waiting area in first floor at ...  Positive
# ..                                                ...       ...
# 82   airindiain now after landing at bangalore air...  Positive
# 83  i literally spent more time  to be precise 1 5...   Neutral
# 84   chaipoint_cares pls take care of service qual...  Positive
# 85   people are waiting for taxis at new bangalore...  Positive
# 86  hey uber  there is a long queue at bangalore a...  Positive
#
# [87 rows x 2 columns]
# Number of Positive Sentiments: 32
# Number of Negative Sentiments: 33
# Number of Neutral Sentiments: 22
# postitive_response 36.7816091954023
# ...

# %%
import pandas as pd
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

data = pd.read_csv("D:\\Internship Progress\\WEEK3\\waiting_area refresh.csv")

text_column = 'full_text'

analyzer = SentimentIntensityAnalyzer()

def classify_sentiment(text):
    sentiment_score = analyzer.polarity_scores(text)
    compound_score = sentiment_score['compound']

    if compound_score >= 0.05:
        return 'Positive'
    elif compound_score <= -0.05:
        return 'Negative'
    else:
        return 'Neutral'

data['sentiment'] = data[text_column].apply(classify_sentiment)
data.to_csv("D:\\Internship Progress\\WEEK3\\waiting_area refresh.csv", index=False)

print(data)

count_positive = 0
count_negative = 0
count_neutral = 0

for sentiment in data['sentiment']:
    if sentiment == 'Positive':
        count_positive += 1
    elif sentiment == 'Negative':
        count_negative += 1
    elif sentiment == 'Neutral':
        count_neutral += 1

print(f"Number of Positive Sentiments: {count_positive}")
print(f"Number of Negative Sentiments: {count_negative}")
print(f"Number of Neutral Sentiments: {count_neutral}")

per1 = 0
per2 = 0
per3 = 0
total = len(data)
positive_response13 = (count_positive / total) * 100
negative_response13 = (count_negative / total) * 100
neutral_response13 = (count_neutral / total) * 100

print("postitive_response", positive_response13)
print("negative_response", negative_response13)
print("neutral_response", neutral_response13)
# Out:
#                                             full_text sentiment
# 0   looks like the waiting area in first floor at ...  Positive
# 1   bangalore airport waiting area  seat with tras...  Positive
# 2    i waited 40 minutes at uber zone for cab at b...  Negative
# 3    blrairport  officejmsc  india  jmscindia  dgc...  Positive
# 4    mediacrooks  rajnathsingh  jayantsinha  naren...   Neutral
# 5    blrairport today i am travelling from bangalo...  Positive
# 6   at bangalore airport going to jaipur   kempego...   Neutral
# 7    crows inside the bangalore airport  crowing a...   Neutral
# 8   a hot sizzling erotic girl sitting in front of...   Neutral
# 9    cutemoments a child sitting in a luggage trol...   Neutral
# 10   atleast 20 passengers waiting for a taxi and ...  Negative
# 11   i remember i was sitting in bangalore airport...   Neutral
# 12   bangalore  airport  nicepic  niceplace   kemp...   Neutral
# 13  there are birds in the bangalore airport waiti...   Neutral
# ...

# %%
import matplotlib.pyplot as plt

# %%
#Cafe Refresh
x=["positive response","negative response","neutral response"]
y=[positive_response1,negative_response1,neutral_response1]
plt.bar(x,y,color=["g","r","y"])
plt.show()

# %%
#Check-IN
x=["positive response","negative response","neutral response"]
y=[positive_response2,negative_response2,neutral_response2]
plt.bar(x,y,color=["g","r","y"])
plt.show()

# %%
#food refresh1
x=["positive response","negative response","neutral response"]
y=[positive_response3,negative_response3,neutral_response3]
plt.bar(x,y,color=["g","r","y"])
plt.show()

# %%
#Hospitality1
x=["positive response","negative response","neutral response"]
y=[positive_response4,negative_response4,neutral_response4]
plt.bar(x,y,color=["g","r","y"])
plt.show()

# %%
#Hospitality2
x=["positive response","negative response","neutral response"]
y=[positive_response5,negative_response5,neutral_response5]
plt.bar(x,y,color=["g","r","y"])
plt.show()

# %%
#Immigration1
x=["positive response","negative response","neutral response"]
y=[positive_response6,negative_response6,neutral_response6]
plt.bar(x,y,color=["g","r","y"])
plt.show()

# %%
#Lounge refresh
x=["positive response","negative response","neutral response"]
y=[positive_response7,negative_response7,neutral_response7]
plt.bar(x,y,color=["g","r","y"])
plt.show()

# %%
#passport
x=["positive response","negative response","neutral response"]
y=[positive_response8,negative_response8,neutral_response8]
plt.bar(x,y,color=["g","r","y"])
plt.show()

# %%
#restaurant refresh
x=["positive response","negative response","neutral response"]
y=[positive_response9,negative_response9,neutral_response9]
plt.bar(x,y,color=["g","r","y"])
plt.show()

# %%
#security check
x=["positive response","negative response","neutral response"]
y=[positive_response10,negative_response10,neutral_response10]
plt.bar(x,y,color=["g","r","y"])
plt.show()

# %%
#visa
x=["positive response","negative response","neutral response"]
y=[positive_response11,negative_response11,neutral_response11]
plt.bar(x,y,color=["g","r","y"])
plt.show()

# %%
#waiting refresh
x=["positive response","negative response","neutral response"]
y=[positive_response12,negative_response12,neutral_response12]
plt.bar(x,y,color=["g","r","y"])
plt.show()

# %%
#waiting area refresh
x=["positive response","negative response","neutral response"]
y=[positive_response13,negative_response13,neutral_response13]
plt.bar(x,y,color=["g","r","y"])
plt.show()

# %%
#Food and Beverages
x=[51.769,18.293,30.002]
plt.pie(x,labels=["Positive","Negative","Neutral"])
plt.title("Food & Beverages")
plt.legend()
plt.show()

# %%
#Hospitality
x1=[59.919,23.638,16.440]
plt.pie(x1,labels=["Positive","Negative","Neutral"])
plt.title("Hospitality")
plt.legend()
plt.show()

# %%
#Immigration
x2=[52.5077,29.767,17.723]
plt.pie(x2,labels=["Positive","Negative","Neutral"])
plt.title("Immigration")
plt.legend()
plt.show()
