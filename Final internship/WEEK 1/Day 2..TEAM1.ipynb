# %%
import requests
import pandas as pd

# %%
twitter_data=[]

# %%
payload={
    'api_key':'5d616b30f117f87b98b00bab3847b1cc',
    'query':'immigration form bangalore airport',
    'num':'50'
}
response=requests.get(
'https://api.scraperapi.com/structured/twitter/search',params=payload
)
data=response.json()

# %%
data
# Out:
# {'search_information': {'query_displayed': 'site:twitter.com "immigration form bangalore airport"',
#   'total_results': 29,
#   'time_taken_displayed': 0.53,
#   'no_results_for_exact_query': True,
#   'query_result_mismatch_message': 'No results found for site:twitter.com "immigration form bangalore airport".Results for site:twitter.com immigration form bangalore airport (without quotes):'},
#  'organic_results': [{'position': 0,
#    'title': 'anand mahindra - Bravo Mumbai Immigration &amp',
#    'snippet': "Bravo Mumbai Immigration &Customs! They've removed those annoying re-checks of passports&customs forms.Easiest global airport to exit. ترجمة التغريدة.",
#    'highlighs': ['Immigration', 'forms', 'airport'],
#    'link': 'https://mobile.twitter.com/anandmahindra/status/750945500476612608?lang=ar-x-fm',
#    'displayed_link': 'https://mobile.twitter.com › anandmahindra › status'},
#   {'position': 1,
#    'title': 'Chaitanya (@BrownPoints) / X',
# ...

# %%
type(data)
# Out:
# dict

# %%
data.keys()
# Out:
# dict_keys(['search_information', 'organic_results', 'pagination'])

# %%
data['pagination']
# Out:
# {'pages_count': 1}

# %%
all_tweets=data['organic_results']
for tweet in all_tweets:
    twitter_data.append(tweet)

# %%
df=pd.DataFrame(twitter_data)
df.to_excel("D:\\Internship Progress\\tweetsImmiogration.xlsx",index=False)
print("File exported")
# Out:
# File exported

# %%
df
# Out:
#     position                                              title  \
# 0          0     anand mahindra - Bravo Mumbai Immigration &amp
# 1          1                       Chaitanya (@BrownPoints) / X
# 2          2              Pranava Tandra (@pranavatandra) / ...
# 3          3                                      Delhi Airport
# 4          4                Varun Mundkur (@varunmundkur) / ...
# 5          5               U.S. Embassy India (@USAndIndia) / X
# 6          6                                     Anshuman Bapna
# 7          7               Arjun Karnata (@KarnataBala1956) ...
# 8          8             Dr. S. Jaishankar (@DrSJaishankar) / X
# 9          9       تويتر \ Somdutta Sengupta (SomduttaSengup3@)
# 10        10            Zorawar Kalra (@ZorawarKalra) / Twitter
# 11        11                   Scott Edmunds (@SCEdmunds) / ...
# 12        12                          Ashu (@ashutoshkojha) / X
# 13        13                   UK in India🇬🇧🇮🇳 (@UKinIndia) / X
# ...
