# %%
import pandas as pd

# %%
df=pd.read_excel("D:\\Internship Progress\\tweetsFood and Beverages.xlsx")

# %%
df=pd.DataFrame(df)

# %%
df
# Out:
#     position                                              title  \
# 0          0                                        BLR Airport
# 1          1                                BLR Airport - X.com
# 2          2                                       anshul gupta
# 3          3                                   Bangalore Mirror
# 4          4                      BLR Airport (@BLRAirport) / X
# 5          5                            BLR Airport - Bengaluru
# 6          6                                        BLR Airport
# 7          7                             5:11 AM · Aug 17, 2019
# 8          8  "In any case, I like homely food only. When I ...
# 9          9                              AJ (@OntheRoadAJ) / X
# 10        10                          Qmin Cafe (@QminCafe) / X
# 11        11                    Vikas Seth (@ChefVikasSeth) / X
# 12        12             M.Samuel Raju (@MSamuelRaju) / Twitter
# 13        13  Sandeep Mukherjee - This costs 180/- in the Ko...
# ...

# %%
df.describe()
# Out:
#         position
# count  90.000000
# mean   44.500000
# std    26.124701
# min     0.000000
# 25%    22.250000
# 50%    44.500000
# 75%    66.750000
# max    89.000000

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# 50    False
# 51    False
# 52    False
# 53    False
# 54    False
# 55    False
# 56    False
# 57    False
# 58    False
# 59    False
# 60    False
# 61    False
# 62    False
# 63    False
# 64    False
# 65    False
# 66    False
# 67    False
# 68    False
# 69    False
# 70    False
# ...

# %%
df=df.drop(columns=['position','title','link','displayed_link','sitelinks'])

# %%
df
# Out:
#                                               snippet  \
# 0   Jul 31, 2023 — ... food & beverages, staff ser...
# 1   Aug 3, 2022 — has opened a new outlet at Depar...
# 2   Sep 25, 2023 — Bangalore airport also earns 70...
# 3   Dec 15, 2020 — The Quad retail and food and be...
# 4   BLR Airport. @BLRAirport. The official account...
# 5   Oct 23, 2021 — #BLRAirport for the live screen...
# 6   May 22, 2022 — Start the weekend off with a ch...
# 7   The #Bangalore airport is clearly one of the b...
# 8   Aug 1, 2022 — At Rustam Bagh in Airport Road i...
# 9   Wandering nomad exploring the world - one city...
# 10  We have more food, more beverages and more rea...
# 11  ... restaurant #industry #Hospitality #Food #B...
# 12  No desert... No soft drinks... Please learn fr...
# 13  Feb 6, 2023 — ... food and water in airports a...
# 14  Bangalore Airport lounge is the best domestic ...
# 15  ... food & beverages, staff service and securi...
# ...

# %%
df['highlighs']==''
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# 50    False
# 51    False
# 52    False
# 53    False
# 54    False
# 55    False
# 56    False
# 57    False
# 58    False
# 59    False
# 60    False
# 61    False
# 62    False
# 63    False
# 64    False
# 65    False
# 66    False
# 67    False
# 68    False
# 69    False
# 70    False
# ...

# %%
df.to_excel("D:\\Internship Progress\\Food and beverages_cleaned.xlsx",index=False)

# %%
df2=pd.read_excel("D:\\Internship Progress\\tweetsHospitality.xlsx")

# %%
df2=pd.DataFrame(df2)

# %%
df2
# Out:
#     position                                              title  \
# 0          0                            Taj Bangalore - Twitter
# 1          1                Taj Bangalore (@TajBangalore) / ...
# 2          2                                            Aviserv
# 3          3                Red Key (@RedKey94155390) / Twitter
# 4          4                                            Aviserv
# 5          5    Hotel Golden Evana (@OtelGoldenEvana) / Twitter
# 6          6        India Retails & Hospitality Private Limited
# 7          7                  Taj Bangalore (@TajBangalore) / X
# 8          8          Hotel Bangalore Gate (@bangaloregate) ...
# 9          9        India Retails & Hospitality Private Limited
# 10        10                               Housefinch Residency
# 11        11        India Retails & Hospitality Private Limited
# 12        12        India Retails & Hospitality Private Limited
# 13        13                                    Prateek Athwani
# ...

# %%
df2=df2.drop(columns=['position','title','link','displayed_link','sitelinks'])

# %%
df2
# Out:
#                                               snippet  \
# 0   May 22, 2019 — Dive into the luxury and unmatc...
# 1   Taj Bangalore is a mere walk away from the Kem...
# 2   Sep 14, 2018 — We're offering a full range of ...
# 3   Red Key is a budget-friendly 2-star hotel in B...
# 4   Sep 14, 2018 — We're offering a full range of ...
# 5   Hotel Golden Evana provides hotel close to Ban...
# 6   India Retails & Hospitality Private Limited .....
# 7   Taj Bangalore is a mere walk away from the Kem...
# 8   A boutique, luxury business hotel, tucked away...
# 9   Oct 18, 2021 — India Retails & Hospitality Pri...
# 10  Most booked hotels near Kempegowda Internation...
# 11  Oct 18, 2021 — Sakkare & Smoor : Sweet Shop at...
# 12  Oct 18, 2021 — INDIAN TRADING CO. at Bangalore...
# 13  Kudos to you guy! Happened to see one incident...
# 14  Taj Bangalore is a mere walk away from the Kem...
# 15  Best hotels & accommodations in Bangalore near...
# ...

# %%
df2.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4      True
# 5     False
# 6     False
# 7      True
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14     True
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# 50    False
# 51    False
# 52    False
# 53    False
# 54    False
# 55    False
# 56    False
# 57    False
# 58    False
# 59    False
# 60    False
# 61    False
# 62    False
# 63    False
# 64    False
# 65    False
# 66    False
# 67    False
# 68    False
# 69    False
# 70    False
# ...

# %%
df2.drop_duplicates()
# Out:
#                                               snippet  \
# 0   May 22, 2019 — Dive into the luxury and unmatc...
# 1   Taj Bangalore is a mere walk away from the Kem...
# 2   Sep 14, 2018 — We're offering a full range of ...
# 3   Red Key is a budget-friendly 2-star hotel in B...
# 5   Hotel Golden Evana provides hotel close to Ban...
# 6   India Retails & Hospitality Private Limited .....
# 8   A boutique, luxury business hotel, tucked away...
# 9   Oct 18, 2021 — India Retails & Hospitality Pri...
# 10  Most booked hotels near Kempegowda Internation...
# 11  Oct 18, 2021 — Sakkare & Smoor : Sweet Shop at...
# 12  Oct 18, 2021 — INDIAN TRADING CO. at Bangalore...
# 13  Kudos to you guy! Happened to see one incident...
# 15  Best hotels & accommodations in Bangalore near...
# 16  Jul 27, 2023 — ... flight to Bangalore and. @a...
# 17  ... -model-at-bengaluru-international-airport/...
# 18  Luxury awaits you only 5km from the Bangalore ...
# ...

# %%
df2.dropna(inplace=True)

# %%
df2
# Out:
#                                               snippet  \
# 0   May 22, 2019 — Dive into the luxury and unmatc...
# 1   Taj Bangalore is a mere walk away from the Kem...
# 2   Sep 14, 2018 — We're offering a full range of ...
# 3   Red Key is a budget-friendly 2-star hotel in B...
# 4   Sep 14, 2018 — We're offering a full range of ...
# 5   Hotel Golden Evana provides hotel close to Ban...
# 6   India Retails & Hospitality Private Limited .....
# 7   Taj Bangalore is a mere walk away from the Kem...
# 8   A boutique, luxury business hotel, tucked away...
# 9   Oct 18, 2021 — India Retails & Hospitality Pri...
# 10  Most booked hotels near Kempegowda Internation...
# 11  Oct 18, 2021 — Sakkare & Smoor : Sweet Shop at...
# 12  Oct 18, 2021 — INDIAN TRADING CO. at Bangalore...
# 13  Kudos to you guy! Happened to see one incident...
# 14  Taj Bangalore is a mere walk away from the Kem...
# 15  Best hotels & accommodations in Bangalore near...
# ...

# %%
df2.loc[:,"highlighs"]
# Out:
# 0     ['hospitality', 'Bangalore', 'Kempegowda Inter...
# 1     ['Bangalore', 'International Airport', 'hotel'...
# 2                            ['Hospitality', 'airport']
# 3      ['hotel in Bangalore', 'Airport', 'hospitality']
# 4                            ['Hospitality', 'airport']
# 5               ['Hotel', 'hotel', 'Bangalore airport']
# 6     ['Hospitality', 'Bangalore Airport', 'Internat...
# 7     ['Bangalore', 'International Airport', 'hotel'...
# 8                                ['hotel', 'Bangalore']
# 9                  ['Hospitality', 'Bangalore Airport']
# 10    ['hotels', 'Kempegowda International Airport',...
# 11                                ['Bangalore Airport']
# 12               ['Bangalore Airport', 'International']
# 13                                ['Bangalore Airport']
# 14    ['Bangalore', 'International Airport', 'hotel'...
# 15    ['hotels', 'Bangalore', 'International Airport...
# 16    ['flight', 'Bangalore', 'hotels', 'Internation...
# ...

# %%
df2.to_excel("D:\\Internship Progress\\Hospitality_cleaned.xlsx",index=False)

# %%
df3=pd.read_excel("D:\\Internship Progress\\tweetsImmigration.xlsx")

# %%
df3
# Out:
#      position                                              title       Date  \
# 0           0     anand mahindra - Bravo Mumbai Immigration &amp 2021-04-01
# 1           1                       Chaitanya (@BrownPoints) / X 2021-12-22
# 2           2              Pranava Tandra (@pranavatandra) / ... 2021-01-30
# 3           3               U.S. Embassy India (@USAndIndia) / X 2021-03-18
# 4           4                                      Delhi Airport 2021-08-14
# 5           5                                     Anshuman Bapna 2021-07-08
# 6           6               Arjun Karnata (@KarnataBala1956) ... 2021-02-20
# 7           7       تويتر \ Somdutta Sengupta (SomduttaSengup3@) 2021-04-10
# 8           8            Zorawar Kalra (@ZorawarKalra) / Twitter 2021-07-22
# 9           9                   Scott Edmunds (@SCEdmunds) / ... 2021-08-04
# 10         10                   UK in India🇬🇧🇮🇳 (@UKinIndia) / X 2021-05-23
# ...

# %%
df3=df3.drop(columns=["position","title","Date","link","displayed_link","sitelinks"])

# %%
df3
# Out:
#                                                snippet  \
# 0    Bravo Mumbai Immigration &Customs! They've rem...
# 1    - Application form - Cover letter with itinera...
# 2    3AM immigration queues at Bangalore Airport. I...
# 3    "Responding to people in need is one of the gu...
# 4    Myy son studying in the US landed at Delhi air...
# 5    Bangalore airport experience was stellar - tru...
# 6    For the same reason we have placed Internation...
# 7    8) at Delhi airport be prepared for various fo...
# 8    Out of the airport with luggage after immigrat...
# 9    China's Ministry of Foreign Affairs announced ...
# 10   As November's AI Safety Summit approaches, gov...
# 11   People of India stand firmly with Israel in th...
# 12   Today at Bengaluru Airport at immigration sect...
# 13   hello i left my bag in the airport express coa...
# 14   Hello bangalore! (derogatory). Image. 3. 10. 3...
# 15   Seatac airport is really well managed. We were...
# ...

# %%
df3.dropna(inplace=True)

# %%
df3
# Out:
#                                                snippet  \
# 0    Bravo Mumbai Immigration &Customs! They've rem...
# 1    - Application form - Cover letter with itinera...
# 2    3AM immigration queues at Bangalore Airport. I...
# 4    Myy son studying in the US landed at Delhi air...
# 5    Bangalore airport experience was stellar - tru...
# 6    For the same reason we have placed Internation...
# 7    8) at Delhi airport be prepared for various fo...
# 8    Out of the airport with luggage after immigrat...
# 9    China's Ministry of Foreign Affairs announced ...
# 11   People of India stand firmly with Israel in th...
# 12   Today at Bengaluru Airport at immigration sect...
# 13   hello i left my bag in the airport express coa...
# 14   Hello bangalore! (derogatory). Image. 3. 10. 3...
# 15   Seatac airport is really well managed. We were...
# 16   PMI Bangalore India · @PMIBangalore. ·. 18.06....
# 18   Ben Gurion International AirPort અને 3 અન્ય. 3...
# ...

# %%
df.to_excel("D:\\Internship Progress\\immigration_cleaned.xlsx",index=False)
