# %%
import pandas as pd
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

data = pd.read_excel('C:\\Users\\91831\\Downloads\\Data.xlsx')

text_column = 'Raw informal sentiments'

analyzer = SentimentIntensityAnalyzer()

def classify_sentiment(text):
    sentiment_score = analyzer.polarity_scores(text)
    compound_score = sentiment_score['compound']

    if compound_score >= 0.05:
        return 'Positive'
    elif compound_score <= -0.05:
        return 'Negative'
    else:
        return 'Neutral'

data['sentiment'] = data[text_column].apply(classify_sentiment)

data.to_csv('D:\\Datasets\\SentimentsClassification.csv', index=False)

print(data)

count_positive = 0
count_negative = 0
count_neutral = 0

for sentiment in data['sentiment']:
    if sentiment == 'Positive':
        count_positive += 1
    elif sentiment == 'Negative':
        count_negative += 1
    elif sentiment == 'Neutral':
        count_neutral += 1

print(f"Number of Positive Sentiments: {count_positive}")
print(f"Number of Negative Sentiments: {count_negative}")
print(f"Number of Neutral Sentiments: {count_neutral}")

per1 = 0
per2 = 0
per3 = 0
total = len(data)
postitive_response = (count_positive / total) * 100
negative_response = (count_negative / total) * 100
neutral_response = (count_neutral / total) * 100

print("postitive_response", postitive_response)
print("negative_response", negative_response)
print("neutral_response", neutral_response)
# Out:
#                               Raw informal sentiments sentiment
# 0                I was not impressed by this product.  Negative
# 1                          Nice headset priced right.  Positive
# 2                      I only hear garbage for audio.   Neutral
# 3                        Excellent bluetooth headset.  Positive
# 4                      It has all the features I want  Positive
# 5   Who in their right mind is gonna buy this batt...   Neutral
# 6   AFTER ARGUING WITH VERIZON REGARDING THE DROPP...  Negative
# 7                          This case seems well made.  Positive
# 8                          Disappointed with battery.  Negative
# 9   Not loud enough and doesn't turn on like it sh...  Negative
# 10  good protection and does not make phone too bu...  Positive
# 11  A usable keyboard actually turns a PDA into a ...  Positive
# 12  This phone is pretty sturdy and I've never had...  Positive
# 13                                 I love this thing!  Positive
# 14  Everything about it is fine and reasonable for...  Positive
# 15                                 VERY DISAPPOINTED.  Negative
# 16  I even dropped this phone into a stream and it...  Positive
# 17  I have been very happy with the 510 and have h...  Positive
# 18                The buttons for on and off are bad.  Negative
# 19  Essentially you can forget Microsoft's tech su...  Positive
# 20  It feels more comfortable than most headsets b...  Positive
# 21                               Great for iPODs too.  Positive
# 22     This device is great in several situations:1.)  Positive
# 23                                  Mic Doesn't work.   Neutral
# 24                                  Absolutely great.  Positive
# 25  The keyboard is a nice compromise between a fu...  Positive
# 26  i got this phone around the end of may and i'm...  Negative
# 27                 It is very comfortable on the ear.  Positive
# 28                       It has been a winner for us.  Positive
# 29                 )Setup couldn't have been simpler.   Neutral
# 30  I've tried several different earpieces for my ...  Positive
# 31                Could not get strong enough signal.  Negative
# 32                 Iam very pleased with my purchase.  Positive
# 33                                       Bad Quality.  Negative
# 34                                 Gets the job done.   Neutral
# 35                                      Great audio!.  Positive
# 36                Basically the service was very bad.  Negative
# 37  it did not work in my cell phone plug i am ver...   Neutral
# Number of Positive Sentiments: 22
# Number of Negative Sentiments: 10
# Number of Neutral Sentiments: 6
# postitive_response 57.89473684210527
# negative_response 26.31578947368421
# neutral_response 15.789473684210526
